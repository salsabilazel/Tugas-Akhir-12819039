# %%
#mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pysheds
# !pip install geopandas
# !pip install fiona
# !pip install natsort
# !pip install pyproj
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pysheds
#   Downloading pysheds-0.3.5-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.6/89.6 kB 10.3 MB/s eta 0:00:00
# Collecting affine (from pysheds)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting geojson (from pysheds)
#   Downloading geojson-3.0.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from pysheds) (0.56.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pysheds) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pysheds) (1.5.3)
# Collecting pyproj (from pysheds)
#   Downloading pyproj-3.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 130.5 MB/s eta 0:00:00
# Collecting rasterio>=1 (from pysheds)
#   Downloading rasterio-1.3.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 106.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from pysheds) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pysheds) (1.10.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio>=1->pysheds) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio>=1->pysheds) (2022.12.7)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio>=1->pysheds) (8.1.3)
# Collecting cligj>=0.5 (from rasterio>=1->pysheds)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting snuggs>=1.4.1 (from rasterio>=1->pysheds)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins (from rasterio>=1->pysheds)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio>=1->pysheds) (67.7.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->pysheds) (0.39.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pysheds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pysheds) (2022.7.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->pysheds) (23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pysheds) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio>=1->pysheds) (3.0.9)
# Installing collected packages: snuggs, pyproj, geojson, cligj, click-plugins, affine, rasterio, pysheds
# Successfully installed affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 geojson-3.0.1 pyproj-3.6.0 pysheds-0.3.5 rasterio-1.3.7 snuggs-1.4.7
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.3 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.4.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 111.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Installing collected packages: fiona, geopandas
# Successfully installed fiona-1.9.4.post1 geopandas-0.13.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (1.9.4.post1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (8.3.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (3.6.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj) (2022.12.7)

# %%
# !pip install shapely --no-binary shapely --force
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shapely
#   Downloading shapely-2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.5/275.5 kB 18.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.14 (from shapely)
#   Downloading numpy-1.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 102.2 MB/s eta 0:00:00
# Building wheels for collected packages: shapely
#   Building wheel for shapely (pyproject.toml) ... done
#   Created wheel for shapely: filename=shapely-2.0.1-cp310-cp310-linux_x86_64.whl size=969708 sha256=2c7ba21ff0a9cf7a75f041aa451a345f7420654664459e89b6938f8667b65323
#   Stored in directory: /root/.cache/pip/wheels/07/bd/06/4e979fa263bca266484ee65f5aab8e6b1c9b20f8caa6f2d7da
# Successfully built shapely
# Installing collected packages: numpy, shapely
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.1
#     Uninstalling shapely-2.0.1:
#       Successfully uninstalled shapely-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.0 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.0 which is incompatible.
# Successfully installed numpy-1.25.0 shapely-2.0.1

# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
import fiona
import geopandas as gpd
import warnings
from shapely import geometry, ops
from pysheds.grid import Grid
from pysheds.view import Raster
from natsort import os_sorted
import pyproj
warnings.filterwarnings('ignore')

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-eafeea46ba0b> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 import matplotlib.colors as colors
# ----> 6 import seaborn as sns
#       7 import fiona
#       8 import geopandas as gpd
#
# /usr/local/lib/python3.10/dist-packages/seaborn/__init__.py in <module>
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in <module>
#      15     _deprecate_ci,
#      16 )
# ---> 17 from ._statistics import EstimateAggregator
#      18 from .axisgrid import FacetGrid, _facet_docs
#      19 from ._docstrings import DocstringComponents, _core_docs
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_statistics.py in <module>
#      29 import pandas as pd
#      30 try:
# ---> 31     from scipy.stats import gaussian_kde
#      32     _no_scipy = False
#      33 except ImportError:
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/__init__.py in <module>
#     483 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     484                                DegenerateDataWarning, FitError)
# --> 485 from ._stats_py import *
#     486 from ._variation import variation
#     487 from .distributions import *
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in <module>
#      35 from numpy import array, asarray, ma
#      36 from numpy.lib import NumpyVersion
# ---> 37 from numpy.testing import suppress_warnings
#      38
#      39 from scipy.spatial.distance import cdist
#
# /usr/local/lib/python3.10/dist-packages/numpy/testing/__init__.py in <module>
#       9
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild
#
# /usr/local/lib/python3.10/dist-packages/numpy/testing/_private/utils.py in <module>
#     415
#     416
# --> 417 @np._no_nep50_warning()
#     418 def assert_almost_equal(actual, desired, decimal=7, err_msg='', verbose=True):
#     419     """
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     313             raise AttributeError(__former_attrs__[attr])
#     314
# --> 315         if attr == 'testing':
#     316             import numpy.testing as testing
#     317             return testing
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'

# %%
# # Buat list untuk menampung DataFrame dari setiap file SHP
# import glob

# # Pola nama file shapefile yang akan dipanggil (misalnya, file_*.shp)
# file_pattern = '/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/shp catchment/catchment_*.shp'

# # Mendapatkan daftar path file shapefile yang cocok dengan pola
# file_paths = glob.glob(file_pattern)[:93]  # Mengambil 93 file pertama

# # Membaca file shapefile pertama ke dalam dataframe geopandas
# merged_data = gpd.read_file(file_paths[0])

# # Menggabungkan file shapefile lainnya ke dalam dataframe
# for file_path in file_paths[1:]:
#     data = gpd.read_file(file_path)
#     merged_data = merged_data.append(data)

# # Menyimpan dataframe hasil penggabungan menjadi satu file shapefile
# merged_data.to_file('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/HASIL/DTA/catchment_gabungan.shp')

# %% [markdown]
# ###Menentukan Luasan Area Catchment

# %%
import shapely
from shapely.geometry import Polygon

# %%
data = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/shp catchment/catchment_1.shp')
data.crs

# %%
from pyproj import CRS

# %%
#geo = data[geometry].to_crs("EPSG:1355")
geo = data[geometry].to_crs(CRS.from_user_input(1355))

# Hitung luas area
# luas_area = geo.area

# # Tambahkan kolom luas area ke dalam data
# geo['Luas_Area'] = luas_area

# geo.to_csv('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/Data excel catchment/Luas Catchment Sumatera.csv')

# %% [markdown]
# ### Membaca Data Raster

# %%
# Membaca data raster
# ----------------------------

grid = Grid.from_raster('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/DEM_SUMATERA.tif')
dem = grid.read_raster('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/DEM_SUMATERA.tif')

# %% [markdown]
# ### Plotting Data DEM

# %% [markdown]
# Referensi : https://mattbartos.com/pysheds/
#
# https://mattbartos.com/pysheds/hand.html
#
# https://pygis.io/docs/c_new_vectors.html

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(dem, extent=grid.extent, cmap='terrain', zorder=1)
plt.colorbar(label='Elevation (m)', shrink=0.65, extend='both')
plt.grid(zorder=0)
plt.title('Digital Elevation Map', size=15)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.tight_layout()

# %% [markdown]
# ### Condition The Elevation Data

# %%
# Condition DEM
# ----------------------
# Fill pits in DEM
pit_filled_dem = grid.fill_pits(dem)

# Fill depressions in DEM
flooded_dem = grid.fill_depressions(pit_filled_dem)

# Resolve flats in DEM
inflated_dem = grid.resolve_flats(flooded_dem)

# %% [markdown]
# ### Elevation To Flow Direction

# %%
# Determine D8 flow directions from DEM
# ----------------------
# Specify directional mapping
dirmap = (64, 128, 1, 2, 4, 8, 16, 32)

# Compute flow directions
# -------------------------------------
fdir = grid.flowdir(inflated_dem, dirmap=dirmap)

# %%
#Plotting
fig = plt.figure(figsize=(8,6))
fig.patch.set_alpha(0)

plt.imshow(fdir, extent=grid.extent, cmap='viridis', zorder=2)
boundaries = ([0] + sorted(list(dirmap)))
plt.colorbar(boundaries= boundaries,
             values=sorted(dirmap), shrink=0.65)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Flow direction grid', size=15)
plt.grid(zorder=-1)
plt.tight_layout()

# %% [markdown]
# flowdir : Generate a flow direction grid from a given digital elevation dataset.

# %% [markdown]
# ### Mengakumulasi arah aliran

# %%
# Calculate flow accumulation
# --------------------------
acc = grid.accumulation(fdir, dirmap=dirmap)

# %%
#Plotting
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)
plt.grid('on', zorder=0)
im = ax.imshow(acc, extent=grid.extent, zorder=2,
               cmap='cubehelix',
               norm=colors.LogNorm(1, acc.max()),
               interpolation='bilinear')
plt.colorbar(im, ax=ax, label='Upstream Cells', shrink=0.65)
plt.title('Flow Accumulation', size=15)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.tight_layout()

# %% [markdown]
# accumulation : Compute the number of cells upstream of each cell; if weights are given, compute the sum of weighted cells upstream of each cell.

# %% [markdown]
# ### Menggambarkan DTA dari arah aliran/flow direction

# %%
#Baca data excel centroid
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/DATA/koordinat_ff.csv')
data

# %%
# Delineate a catchment
for j in (data.index):
  x = data.loc[j,'Lon']
  y = data.loc[j,'Lat']
# Specify pour point/outlet
# x, y =-0.921, 100.438

# Reset view
  grid.viewfinder = fdir.viewfinder

# Compute accumulation
  acc = grid.accumulation(fdir)

# Snap pour point to high accumulation cell
  x_snap, y_snap = grid.snap_to_mask(acc > 1000, (x, y))

# Delineate the catchment
  catch = grid.catchment(x=x_snap, y=y_snap, fdir=fdir, dirmap=dirmap,
                         xytype='coordinate')

# Crop and plot the catchment
# ---------------------------
# Clip the bounding box to the catchment
  grid.clip_to(catch)
  clipped_catch = grid.view(catch)

# Calling grid.polygonize without arguments will default to the catchment mask
  shapes = grid.polygonize()

  schema = {
      'geometry': 'Polygon',
      'properties': {'LABEL': 'float:16'}
      }

  with fiona.open('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/HASIL/Catchment/Catchment{}.shp'.format(j+1), 'w',
                  driver='ESRI Shapefile',
                  crs=grid.crs.srs,
                  schema=schema) as c:
    i = 0
    for shape, value in shapes:
      rec = {}
      rec['geometry'] = shape
      rec['properties'] = {'LABEL' : str(value)}
      rec['id'] = str(i)
      c.write(rec)
      i += 1

  shp = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/TA/SIDANG/HASIL/Catchment/Catchment{}.shp'.format(i+1))
  shp.head()

# %%
# copy GeoDataFrame
points = shp.copy()
# change geometry
points['geometry'] = points['geometry'].centroid
points.head()

# %%
# Plotting
# Plot the catchment
fig, ax = plt.subplots(figsize=(8,6))
fig.patch.set_alpha(0)

plt.grid('on', zorder=0)
im = ax.imshow(np.where(clipped_catch, clipped_catch, np.nan), extent=grid.extent,
               zorder=1.5, cmap='Greys_r')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Delineated Catchment', size=15)

# %% [markdown]
# snap_to_mask : Snaps a set of points to the nearest nonzero cell in a boolean mask; useful for finding pour points from an accumulation raster

# %% [markdown]
# ### Ubah Ke Bentuk Shapefile

# %% [markdown]
# Referensi: https://github.com/mdbartos/pysheds/blob/master/recipes/write_shapefile.ipynb

# %%
# Calling grid.polygonize without arguments will default to the catchment mask
shapes = grid.polygonize()

# Is equivalent to...
#shapes = catch.polygonize(grid.mask.astype(np.uint8))

# %%
schema = {
    'geometry': 'Polygon',
    'properties': {'LABEL': 'float:16'}
}

with fiona.open('/content/drive/MyDrive/Colab Notebooks/TA/Data Sungai/Catchment1.shp', 'w',
                driver='ESRI Shapefile',
                crs=grid.crs.srs,
                schema=schema) as c:
    i = 0
    for shape, value in shapes:
        rec = {}
        rec['geometry'] = shape
        rec['properties'] = {'LABEL' : str(value)}
        rec['id'] = str(i)
        c.write(rec)
        i += 1

# %%
shp = gpd.read_file('/content/drive/MyDrive/Colab Notebooks/TA/Data Sungai/Catchment1.shp')
shp.head()

# %% [markdown]
# ### Ubah Shapefile ke Titik Berat/Centroid

# %%
# copy GeoDataFrame
points = shp.copy()
# change geometry
points['geometry'] = points['geometry'].centroid
points.head()

# %% [markdown]
# ### Membaca Data Kondisi Atmosfer (Netcdf)

# %%
#Load data sebagai data array
cape=xr.load_dataarray('/content/drive/MyDrive/Bismillah TA/TA/Data/cape.nc')

#min_lat = -0.7943954
#max_lat = -0.5443954
#min_lon = 100.179249
#max_lon = 100.429249

#min_lat = -0.8
#max_lat = -0.55
#min_lon = 100.25
#max_lon = 100.5

#cropped_cape = cape.sel(latitude=slice(min_lat,max_lat), longitude=slice(min_lon,max_lon))
cropped_cape = cape.sel(longitude=100.429, latitude=-0.794, method='nearest')
df = cropped_cape.to_dataframe()
df = pd.DataFrame(df)

# %%
df

# %%
cape
